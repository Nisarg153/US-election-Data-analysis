# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

sns.set_style('darkgrid')
plt.rcParams['font.size'] = 14
plt.rcParams['figure.figsize'] = (9,5)
plt.rcParams['figure.facecolor'] = '#00000000'

# %%
election_df = pd.read_csv('1976_2020_president.csv')

# %%
election_df
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
# ...

# %% [markdown]
# # Checking the NaN values

# %%
election_df.isna().sum()
# Out:
# year                   0
# state                  0
# state_po               0
# state_fips             0
# state_cen              0
# state_ic               0
# office                 0
# candidate            287
# party_detailed       456
# writein                3
# candidatevotes         0
# totalvotes             0
# version                0
# notes               4287
# party_simplified       0
# dtype: int64

# %% [markdown]
# As we have total records 4287 in the dataset and in the notes column there are also 4287 NaN values.
# it indicates that we do not need notes column.
# Office and version has the same value all along.
# so we can drop notes, office and version columns.

# %%
election_df.drop(['notes', 'office', 'version'], axis = 1, inplace=True)

# %%
election_df.isna().sum()
# Out:
# year                  0
# state                 0
# state_po              0
# state_fips            0
# state_cen             0
# state_ic              0
# candidate           287
# party_detailed      456
# writein               3
# candidatevotes        0
# totalvotes            0
# party_simplified      0
# dtype: int64

# %%
election_df['party_detailed'].fillna("Unknown", inplace=True)

# %%
election_df.dropna(subset = ['writein'], inplace = True)

# %%
election_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4284 entries, 0 to 4286
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              4284 non-null   int64
#  1   state             4284 non-null   object
#  2   state_po          4284 non-null   object
#  3   state_fips        4284 non-null   int64
#  4   state_cen         4284 non-null   int64
#  5   state_ic          4284 non-null   int64
#  6   candidate         3998 non-null   object
#  7   party_detailed    4284 non-null   object
#  8   writein           4284 non-null   object
#  9   candidatevotes    4284 non-null   int64
#  10  totalvotes        4284 non-null   int64
#  11  party_simplified  4284 non-null   object
# dtypes: int64(6), object(6)
# memory usage: 435.1+ KB
